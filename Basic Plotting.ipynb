# %%
# A handy tutorial/explanation to plotting in python is also available at 
# http://www.pybloggers.com/2018/02/python-plotting-with-matplotlib-guide/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_list1 = 500.*np.random.rand(500)
random_list2 = 250.*np.random.rand(500)

x = np.arange(100, 0.1)
y = 5*x*x - 2.3*x - 6

# %% [markdown]
# ## The first way to plot

# %%
plt.figure(figsize = (5, 5))

plt.scatter(random_list1[::-1], random_list1, marker = 'o', s = 50)
plt.scatter(random_list2[::-1], random_list2, color = 'r', marker = 'x', s = 54)

# It is curious that tickmarks and labels are different attributes of the plot

plt.xticks(fontsize=12, rotation=90)
#plt.yticks(fontsize=12, rotation=90)

plt.xlabel('weight', fontsize=12)
plt.ylabel('height', fontsize=12)
# Out:
# Text(0,0.5,'height')

# %% [markdown]
# ## The other way

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

csfont = {'fontname':'Comic Sans MS'}
hfont = {'fontname':'Times New Roman'}

fig, ax = plt.subplots(figsize=(5,5))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')

ax.set_title('Combined debt growth over time',**csfont, fontsize=15)
ax.set_xlabel('Years', **hfont, fontsize=15)


ax.legend(loc='upper left')
#ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()

# %%
rng + rnd
# Out:
# array([[ 6,  4,  8,  8, 12, 10,  6, 13, 15, 11, 15, 13, 18, 21, 16, 22,
#         23, 23, 21, 27, 24, 25, 25, 29, 31, 34, 30, 27, 28, 29, 33, 34,
#         38, 42, 37, 40, 44, 39, 45, 47, 49, 50, 51, 45, 51, 53, 55, 48,
#         52, 56],
#        [ 8,  2,  4,  5,  4, 11,  8, 10, 16, 16, 19, 16, 12, 15, 15, 22,
#         23, 24, 20, 25, 24, 21, 24, 24, 30, 26, 31, 31, 30, 36, 31, 37,
#         33, 41, 34, 40, 37, 41, 38, 44, 45, 45, 47, 47, 50, 51, 55, 52,
#         53, 57],
#        [ 6,  6,  5, 12,  6, 11, 12, 10, 11, 12, 11, 20, 20, 16, 21, 16,
#         25, 26, 27, 21, 24, 26, 25, 30, 33, 34, 35, 33, 30, 36, 35, 36,
#         36, 39, 37, 40, 36, 46, 39, 43, 44, 47, 47, 46, 53, 45, 52, 53,
#         55, 54]])
